# %% [markdown]
# This is Luke's 2.0 d4d work.
#
# All you would need to do to run this is update
#
#  os.chdir('C:\\Users\\...\\geojsons')
#
#  and
#
#  curr_target_dir_path = 'C:\\Users\\...\\geojsons\\' + curr_target_dir
#
#  in the 4th and 5th cell (this cell being the 1st cell)
#
#
# As of now this program:
# Enters a folder in 'geojsons', then:
#
# loads arrival and departure files, pulls some data from each file,  exits folder
#
# and repeats for next folder.
#
# Next step is to allow user to easily filter such as the following coordinate box provided by connor:
# 1 - (33.272014, 42.447810), 2 - (33.068781, 41.775133), 3 - ( 32.116345, 42.469610), 4 - (32.394570, 43.127131)
#
# **UPDATE**:
#
# I now plan to make each of the 265 arrival dates and each of the 265 departure dates (which contain same dates) as their own dataframe that can be loaded into a graph(or heat map).
#
# Once we can do that we should be able to display arrival data and departures data in different colors.
#
# So showing 1 particular date (out of the 265 possible dates) would display arrival data in say green and departure data in say blue (or somthing). The trick would be to choose what data to display.

# %%
import pandas as pd
import numpy as np 
import geopandas as gpd

# %%
import scipy.stats as stats
import math
import matplotlib.pylab as plt
# %matplotlib inline
import os

# %%
arrival_date_list = ['2018-11-13', '2018-11-14', '2018-11-15', '2018-11-16', '2018-11-17', '2018-11-18', '2018-11-19', '2018-11-20', '2018-11-21', '2018-11-22', '2018-11-23', '2018-11-24', '2018-11-25', '2018-11-26', '2018-11-27', '2018-11-28', '2018-11-29', '2018-11-30', '2018-12-01', '2018-12-02', '2018-12-03', '2018-12-04', '2018-12-05', '2018-12-07', '2018-12-08', '2018-12-09', '2018-12-10', '2018-12-11', '2018-12-12', '2018-12-13', '2018-12-14', '2018-12-15', '2018-12-16', '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-21', '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25', '2018-12-29', '2018-12-30', '2018-12-31', '2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04', '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12', '2019-01-13', '2019-01-14', '2019-01-15', '2019-01-18', '2019-01-19', '2019-01-20', '2019-01-21', '2019-01-22', '2019-01-24', '2019-01-26', '2019-01-27', '2019-01-28', '2019-01-29', '2019-01-30', '2019-01-31', '2019-02-01', '2019-02-02', '2019-02-03', '2019-02-04', '2019-02-07', '2019-02-08', '2019-02-09', '2019-02-10', '2019-02-11', '2019-02-13', '2019-02-14', '2019-02-15', '2019-02-16', '2019-02-19', '2019-02-20', '2019-02-21', '2019-02-22', '2019-03-02', '2019-03-03', '2019-03-04', '2019-03-05', '2019-03-06', '2019-03-08', '2019-03-09', '2019-03-10', '2019-03-11', '2019-03-12', '2019-03-13', '2019-03-15', '2019-03-16', '2019-03-17', '2019-03-18', '2019-03-21', '2019-03-23', '2019-03-25', '2019-03-27', '2019-03-28', '2019-03-29', '2019-03-30', '2019-03-31', '2019-04-01', '2019-04-02', '2019-04-03', '2019-04-04', '2019-04-05', '2019-04-08', '2019-04-10', '2019-04-11', '2019-04-17', '2019-04-20', '2019-04-21', '2019-04-22', '2019-04-23', '2019-04-25', '2019-04-27', '2019-04-28', '2019-04-29', '2019-05-02', '2019-05-03', '2019-05-04', '2019-05-06', '2019-05-08', '2019-05-14', '2019-05-15', '2019-05-16', '2019-05-17', '2019-05-18', '2019-05-19', '2019-05-21', '2019-05-22', '2019-05-23', '2019-05-24', '2019-05-26', '2019-05-27', '2019-05-28', '2019-05-29', '2019-05-30', '2019-05-31', '2019-06-01', '2019-06-02', '2019-06-03', '2019-06-04', '2019-06-05', '2019-06-07', '2019-06-08', '2019-06-09', '2019-06-10', '2019-06-11', '2019-06-14', '2019-06-15', '2019-06-17', '2019-06-18', '2019-06-21', '2019-06-23', '2019-06-24', '2019-06-25', '2019-06-28', '2019-06-16', '2019-06-29', '2019-06-30', '2019-06-19', '2019-06-22', '2019-07-07', '2019-07-08', '2019-06-27', '2019-07-09', '2019-07-10', '2019-07-11', '2019-07-01', '2019-07-13', '2019-07-02', '2019-07-14', '2019-07-15', '2019-07-16', '2019-07-17', '2019-07-06', '2019-07-18', '2019-07-19', '2019-07-20', '2019-07-21', '2019-07-22', '2019-07-24', '2019-07-26', '2019-07-27', '2019-07-28', '2019-07-29', '2019-07-30', '2019-07-31', '2019-08-01', '2019-08-02', '2019-08-03', '2019-08-04', '2019-08-05', '2019-08-06', '2019-08-07', '2019-08-08', '2019-08-09', '2019-08-10', '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15', '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21', '2019-08-22', '2019-08-24', '2019-08-25', '2019-08-26', '2019-08-27', '2019-08-28', '2019-08-29', '2019-08-31', '2019-09-02', '2019-09-03', '2019-09-04', '2019-09-05', '2019-09-06', '2019-09-07', '2019-09-08', '2019-09-10', '2019-09-12', '2019-09-13', '2019-09-14', '2019-09-15', '2019-09-16', '2019-09-17', '2019-09-18', '2019-09-19', '2019-09-20', '2019-09-21', '2019-09-22', '2019-09-23', '2019-09-25', '2019-09-30', '2019-10-02', '2019-10-04', '2019-10-05', '2019-10-06', '2019-10-07', '2019-10-08', '2019-10-10', '2019-10-17', '2019-10-18', '2019-10-19', '2019-10-20', '2019-10-22', '2019-10-23', '2019-10-25', '2019-10-26', '2019-10-27', '2019-10-28', '2019-10-30']
departure_date_list = ['2018-11-01', '2018-11-02', '2018-11-03', '2018-11-04', '2018-11-05', '2018-11-06', '2018-11-07', '2018-11-08', '2018-11-09', '2018-11-10', '2018-11-11', '2018-11-12', '2018-11-13', '2018-11-14', '2018-11-15', '2018-11-16', '2018-11-17', '2018-11-18', '2018-11-19', '2018-11-20', '2018-11-21', '2018-11-22', '2018-11-23', '2018-11-25', '2018-11-26', '2018-11-27', '2018-11-28', '2018-11-29', '2018-11-30', '2018-12-01', '2018-12-02', '2018-12-03', '2018-12-04', '2018-12-05', '2018-12-06', '2018-12-07', '2018-12-09', '2018-12-10', '2018-12-11', '2018-12-12', '2018-12-13', '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20', '2018-12-21', '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25', '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-29', '2018-12-30', '2018-12-31', '2019-01-01', '2019-01-02', '2019-01-03', '2019-01-06', '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-12', '2019-01-14', '2019-01-15', '2019-01-16', '2019-01-17', '2019-01-18', '2019-01-19', '2019-01-20', '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-26', '2019-01-27', '2019-01-28', '2019-01-29', '2019-01-30', '2019-02-01', '2019-02-02', '2019-02-03', '2019-02-04', '2019-02-07', '2019-02-08', '2019-02-09', '2019-02-10', '2019-02-18', '2019-02-19', '2019-02-20', '2019-02-21', '2019-02-22', '2019-02-24', '2019-02-25', '2019-02-26', '2019-02-27', '2019-02-28', '2019-03-01', '2019-03-03', '2019-03-04', '2019-03-05', '2019-03-06', '2019-03-09', '2019-03-11', '2019-03-13', '2019-03-15', '2019-03-16', '2019-03-17', '2019-03-18', '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22', '2019-03-23', '2019-03-24', '2019-03-27', '2019-03-29', '2019-03-30', '2019-04-05', '2019-04-08', '2019-04-09', '2019-04-10', '2019-04-11', '2019-04-13', '2019-04-15', '2019-04-16', '2019-04-17', '2019-04-20', '2019-04-21', '2019-04-22', '2019-04-24', '2019-04-26', '2019-05-02', '2019-05-03', '2019-05-04', '2019-05-05', '2019-05-06', '2019-05-07', '2019-05-09', '2019-05-10', '2019-05-11', '2019-05-12', '2019-05-14', '2019-05-15', '2019-05-16', '2019-05-17', '2019-05-18', '2019-05-19', '2019-05-20', '2019-05-21', '2019-05-22', '2019-05-23', '2019-05-24', '2019-05-26', '2019-05-27', '2019-05-28', '2019-05-29', '2019-05-30', '2019-06-02', '2019-06-03', '2019-06-05', '2019-06-06', '2019-06-09', '2019-06-11', '2019-06-12', '2019-06-13', '2019-06-16', '2019-06-04', '2019-06-17', '2019-06-18', '2019-06-07', '2019-06-10', '2019-06-25', '2019-06-26', '2019-06-15', '2019-06-27', '2019-06-28', '2019-06-29', '2019-06-19', '2019-07-01', '2019-06-20', '2019-07-02', '2019-07-03', '2019-07-04', '2019-07-05', '2019-06-24', '2019-07-06', '2019-07-07', '2019-07-08', '2019-07-09', '2019-07-10', '2019-07-12', '2019-07-14', '2019-07-15', '2019-07-16', '2019-07-17', '2019-07-18', '2019-07-19', '2019-07-20', '2019-07-21', '2019-07-22', '2019-07-23', '2019-07-24', '2019-07-25', '2019-07-26', '2019-07-27', '2019-07-28', '2019-07-29', '2019-07-31', '2019-08-01', '2019-08-02', '2019-08-03', '2019-08-04', '2019-08-07', '2019-08-08', '2019-08-09', '2019-08-10', '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15', '2019-08-16', '2019-08-17', '2019-08-19', '2019-08-21', '2019-08-22', '2019-08-23', '2019-08-24', '2019-08-25', '2019-08-26', '2019-08-27', '2019-08-29', '2019-08-31', '2019-09-01', '2019-09-02', '2019-09-03', '2019-09-04', '2019-09-05', '2019-09-06', '2019-09-07', '2019-09-08', '2019-09-09', '2019-09-10', '2019-09-11', '2019-09-13', '2019-09-18', '2019-09-20', '2019-09-22', '2019-09-23', '2019-09-24', '2019-09-25', '2019-09-26', '2019-09-28', '2019-10-05', '2019-10-06', '2019-10-07', '2019-10-08', '2019-10-10', '2019-10-11', '2019-10-13', '2019-10-14', '2019-10-15', '2019-10-16', '2019-10-18']

# %%
os.chdir('C:\\Users\\luker\\Desktop\\d4d_work\\geojsons')

#arrival_date_list = [] # track all dates of arrivals
#departure_date_list = [] # track all dates of departures

dir_list = os.listdir('.') 
print("Number of folders containing geojson arrival/departure file pairs: " + str(len(dir_list)))
print("")
for i in range(1):
 
    #file setup 
    curr_target_dir = dir_list[i]
    curr_target_dir_path = 'C:\\Users\\luker\\Desktop\\d4d_work\\geojsons\\' + curr_target_dir
    os.chdir(curr_target_dir_path)
    file_list = os.listdir('.') 
    arrivalfname = r""+file_list[0] #arrival is always first (but also checked with if statement in processing code)
    dfArrival = gpd.read_file(arrivalfname)
    departurefname = r""+file_list[1]      
    dfDeparture = gpd.read_file(departurefname)
    
    #arrival file processing
    if dfArrival['detect_type'][0] == 'Arrival':
        print("---------- Processing arrival: " + str(i) + " ----------")
        
        arrival_date = dfArrival['timestamp'][0]
        arrival_date = arrival_date[0:10]
        if arrival_date not in arrival_date_list:
            arrival_date_list.append(arrival_date)
            
        dfArrivalDescribe = dfArrival.describe()
        arrival_count = dfArrivalDescribe['change_area'][0]
        print("arrival_date: " + str(arrival_date))
        print("arrival_count: " + str(arrival_count))
        print("")
        
        #change_area
        arrival_min_change_area = round( (dfArrivalDescribe['change_area'][3]) ,2)
        arrival_mean_change_area = round( (dfArrivalDescribe['change_area'][1]) ,2)
        arrival_median_change_area = round( (dfArrivalDescribe['change_area'][5]) ,2)
        arrival_max_change_area = round( (dfArrivalDescribe['change_area'][7]) ,2)
        arrival_std_change_area = round( (dfArrivalDescribe['change_area'][2]) ,2)
        arrival_iqr_change_area = round( ((dfArrivalDescribe['change_area'][6])-(dfArrivalDescribe['change_area'][4])) ,2)
        print("arrival_min_change_area: " + str(arrival_min_change_area))
        print("arrival_mean_change_area: " + str(arrival_mean_change_area))
        print("arrival_median_change_area: " + str(arrival_median_change_area))
        print("arrival_max_change_area: " + str(arrival_max_change_area))
        print("arrival_std_change_area: " + str(arrival_std_change_area))
        print("arrival_iqr_change_area: " + str(arrival_iqr_change_area))
        print("")
        
        #pixel_count
        arrival_min_pixel_count = round( (dfArrivalDescribe['pixel_count'][3]) ,1)
        arrival_mean_pixel_count = round( (dfArrivalDescribe['pixel_count'][1]) ,1)
        arrival_median_pixel_count = round( (dfArrivalDescribe['pixel_count'][5]) ,1)
        arrival_max_pixel_count = round( (dfArrivalDescribe['pixel_count'][7]) ,1)
        arrival_std_pixel_count = round( (dfArrivalDescribe['pixel_count'][2]) ,1)
        arrival_iqr_pixel_count = round( ((dfArrivalDescribe['pixel_count'][6])-(dfArrivalDescribe['pixel_count'][4])) ,1)
        print("arrival_min_pixel_count: " + str(arrival_min_pixel_count))
        print("arrival_mean_pixel_count: " + str(arrival_mean_pixel_count))
        print("arrival_median_pixel_count: " + str(arrival_median_pixel_count))
        print("arrival_max_pixel_count: " + str(arrival_max_pixel_count))
        print("arrival_std_pixel_count: " + str(arrival_std_pixel_count))
        print("arrival_iqr_pixel_count: " + str(arrival_iqr_pixel_count))
        print("")
        
        #perimeter
        arrival_min_perimeter = round( (dfArrivalDescribe['perimeter'][3]) ,2)
        arrival_mean_perimeter = round( (dfArrivalDescribe['perimeter'][1]) ,2)
        arrival_median_perimeter = round( (dfArrivalDescribe['perimeter'][5]) ,2)
        arrival_max_perimeter = round( (dfArrivalDescribe['perimeter'][7]) ,2)
        arrival_std_perimeter = round( (dfArrivalDescribe['perimeter'][2]) ,2)
        arrival_iqr_perimeter = round( ((dfArrivalDescribe['perimeter'][6])-(dfArrivalDescribe['perimeter'][4])) ,2)
        print("arrival_min_perimeter: " + str(arrival_min_perimeter))
        print("arrival_mean_perimeter: " + str(arrival_mean_perimeter))
        print("arrival_median_perimeter: " + str(arrival_median_perimeter))
        print("arrival_max_perimeter: " + str(arrival_max_perimeter))
        print("arrival_std_perimeter: " + str(arrival_std_perimeter))
        print("arrival_iqr_perimeter: " + str(arrival_iqr_perimeter))
        print("")
        
        #target_mean_return
        arrival_min_target_mean_return = round( (dfArrivalDescribe['target_mean_return'][3]) ,2)
        arrival_mean_target_mean_return = round( (dfArrivalDescribe['target_mean_return'][1]) ,2)
        arrival_median_target_mean_return = round( (dfArrivalDescribe['target_mean_return'][5]) ,2)
        arrival_max_target_mean_return = round( (dfArrivalDescribe['target_mean_return'][7]) ,2)
        arrival_std_target_mean_return = round( (dfArrivalDescribe['target_mean_return'][2]) ,2)
        arrival_iqr_target_mean_return = round( ((dfArrivalDescribe['target_mean_return'][6])-(dfArrivalDescribe['target_mean_return'][4])) ,2)
        print("arrival_min_target_mean_return: " + str(arrival_min_target_mean_return))
        print("arrival_mean_target_mean_return: " + str(arrival_mean_target_mean_return))
        print("arrival_median_target_mean_return: " + str(arrival_median_target_mean_return))
        print("arrival_max_target_mean_return: " + str(arrival_max_target_mean_return))
        print("arrival_std_target_mean_return: " + str(arrival_std_target_mean_return))
        print("arrival_iqr_target_mean_return: " + str(arrival_iqr_target_mean_return))
        print("")
        
        #weighted_centroid_lat
        arrival_min_weighted_lat = round( (dfArrivalDescribe['weighted_centroid_lat'][3]) ,6)
        arrival_mean_weighted_lat = round( (dfArrivalDescribe['weighted_centroid_lat'][1]) ,6)
        arrival_max_weighted_lat = round( (dfArrivalDescribe['weighted_centroid_lat'][7]) ,6)
        print("arrival_min_weighted_lat: " + str(arrival_min_weighted_lat))
        print("arrival_mean_weighted_lat: " + str(arrival_mean_weighted_lat))
        print("arrival_max_weighted_lat: " + str(arrival_max_weighted_lat))
        print("")
        
        #weighted_centroid_lon
        arrival_min_weighted_lon = round( (dfArrivalDescribe['weighted_centroid_lon'][3]) ,6)
        arrival_mean_weighted_lon = round( (dfArrivalDescribe['weighted_centroid_lon'][1]) ,6)
        arrival_max_weighted_lon = round( (dfArrivalDescribe['weighted_centroid_lon'][7]) ,6)
        print("arrival_min_weighted_lon: " + str(arrival_min_weighted_lon))
        print("arrival_mean_weighted_lon: " + str(arrival_mean_weighted_lon))
        print("arrival_max_weighted_lon: " + str(arrival_max_weighted_lon))
        print("")        
                 
            
    #departure file processing
    if dfDeparture['detect_type'][0] == 'Departure':
        print("---------- Processing departure: " + str(i) + " ----------")
        
        departure_date = dfDeparture['timestamp'][0]
        departure_date = departure_date[0:10]
        if departure_date not in departure_date_list:
            departure_date_list.append(departure_date)
            
        dfDepartureDescribe = dfDeparture.describe()     
        departure_count = dfDepartureDescribe['change_area'][0]
        print("departure_date: " + str(departure_date))
        print("departure_count: " + str(departure_count))
        print("")
        #change_area
        departure_min_change_area = round( (dfDepartureDescribe['change_area'][3]) ,2)
        departure_mean_change_area = round( (dfDepartureDescribe['change_area'][1]) ,2)
        departure_median_change_area = round( (dfDepartureDescribe['change_area'][5]) ,2)
        departure_max_change_area = round( (dfDepartureDescribe['change_area'][7]) ,2)
        departure_std_change_area = round( (dfDepartureDescribe['change_area'][2]) ,2)
        departure_iqr_change_area = round( ((dfDepartureDescribe['change_area'][6])-(dfDepartureDescribe['change_area'][4])) ,2)
        print("departure_min_change_area: " + str(departure_min_change_area))
        print("departure_mean_change_area: " + str(departure_mean_change_area))
        print("departure_median_change_area: " + str(departure_median_change_area))
        print("departure_max_change_area: " + str(departure_max_change_area))
        print("departure_std_change_area: " + str(departure_std_change_area))
        print("departure_iqr_change_area: " + str(departure_iqr_change_area))
        print("")
        
        #pixel_count
        departure_min_pixel_count = round( (dfDepartureDescribe['pixel_count'][3]) ,1)
        departure_mean_pixel_count = round( (dfDepartureDescribe['pixel_count'][1]) ,1)
        departure_median_pixel_count = round( (dfDepartureDescribe['pixel_count'][5]) ,1)
        departure_max_pixel_count = round( (dfDepartureDescribe['pixel_count'][7]) ,1)
        departure_std_pixel_count = round( (dfDepartureDescribe['pixel_count'][2]) ,1)
        departure_iqr_pixel_count = round( ((dfDepartureDescribe['pixel_count'][6])-(dfDepartureDescribe['pixel_count'][4])) ,1)
        print("departure_min_pixel_count: " + str(departure_min_pixel_count))
        print("departure_mean_pixel_count: " + str(departure_mean_pixel_count))
        print("departure_median_pixel_count: " + str(departure_median_pixel_count))
        print("departure_max_pixel_count: " + str(departure_max_pixel_count))
        print("departure_std_pixel_count: " + str(departure_std_pixel_count))
        print("departure_iqr_pixel_count: " + str(departure_iqr_pixel_count))
        print("")
        
        #perimeter
        departure_min_perimeter = round( (dfDepartureDescribe['perimeter'][3]) ,2)
        departure_mean_perimeter = round( (dfDepartureDescribe['perimeter'][1]) ,2)
        departure_median_perimeter = round( (dfDepartureDescribe['perimeter'][5]) ,2)
        departure_max_perimeter = round( (dfDepartureDescribe['perimeter'][7]) ,2)
        departure_std_perimeter = round( (dfDepartureDescribe['perimeter'][2]) ,2)
        departure_iqr_perimeter = round( ((dfDepartureDescribe['perimeter'][6])-(dfDepartureDescribe['perimeter'][4])) ,2)
        print("departure_min_perimeter: " + str(departure_min_perimeter))
        print("departure_mean_perimeter: " + str(departure_mean_perimeter))
        print("departure_median_perimeter: " + str(departure_median_perimeter))
        print("departure_max_perimeter: " + str(departure_max_perimeter))
        print("departure_std_perimeter: " + str(departure_std_perimeter))
        print("departure_iqr_perimeter: " + str(departure_iqr_perimeter))
        print("")
        
        #target_mean_return
        departure_min_target_mean_return = round( (dfDepartureDescribe['target_mean_return'][3]) ,2)
        departure_mean_target_mean_return = round( (dfDepartureDescribe['target_mean_return'][1]) ,2)
        departure_median_target_mean_return = round( (dfDepartureDescribe['target_mean_return'][5]) ,2)
        departure_max_target_mean_return = round( (dfDepartureDescribe['target_mean_return'][7]) ,2)
        departure_std_target_mean_return = round( (dfDepartureDescribe['target_mean_return'][2]) ,2)
        departure_iqr_target_mean_return = round( ((dfDepartureDescribe['target_mean_return'][6])-(dfDepartureDescribe['target_mean_return'][4])) ,2)
        print("departure_min_target_mean_return: " + str(departure_min_target_mean_return))
        print("departure_mean_target_mean_return: " + str(departure_mean_target_mean_return))
        print("departure_median_target_mean_return: " + str(departure_median_target_mean_return))
        print("departure_max_target_mean_return: " + str(departure_max_target_mean_return))
        print("departure_std_target_mean_return: " + str(departure_std_target_mean_return))
        print("departure_iqr_target_mean_return: " + str(departure_iqr_target_mean_return))
        print("")
        
        #weighted_centroid_lat
        departure_min_weighted_lat = round( (dfDepartureDescribe['weighted_centroid_lat'][3]) ,6)
        departure_mean_weighted_lat = round( (dfDepartureDescribe['weighted_centroid_lat'][1]) ,6)
        departure_max_weighted_lat = round( (dfDepartureDescribe['weighted_centroid_lat'][7]) ,6)
        print("departure_min_weighted_lat: " + str(departure_min_weighted_lat))
        print("departure_mean_weighted_lat: " + str(departure_mean_weighted_lat))
        print("departure_max_weighted_lat: " + str(departure_max_weighted_lat))
        print("")
        
        #weighted_centroid_lon
        departure_min_weighted_lon = round( (dfDepartureDescribe['weighted_centroid_lon'][3]) ,6)
        departure_mean_weighted_lon = round( (dfDepartureDescribe['weighted_centroid_lon'][1]) ,6)
        departure_max_weighted_lon = round( (dfDepartureDescribe['weighted_centroid_lon'][7]) ,6)
        print("departure_min_weighted_lon: " + str(departure_min_weighted_lon))
        print("departure_mean_weighted_lon: " + str(departure_mean_weighted_lon))
        print("departure_max_weighted_lon: " + str(departure_max_weighted_lon))
        print("")
        
    #arrival_date_count_list.append(arrival_tuple)
    #departure_date_count_list.append(departure_tuple) 

print("")
print("arrival_date_list: ")
print(arrival_date_list)
print("departure_date_list: ")
print(departure_date_list)
# Out:
# Number of folders containing geojson arrival/departure file pairs: 1159
#
# ---------- Processing arrival: 0 ----------
# arrival_date: 2018-11-13
# arrival_count: 5237.0
#
# arrival_min_change_area: 282.28
# arrival_mean_change_area: 606.28
# arrival_median_change_area: 422.29
# arrival_max_change_area: 18782.78
# arrival_std_change_area: 673.58
# arrival_iqr_change_area: 241.31
#
# arrival_min_pixel_count: 6.0
# arrival_mean_pixel_count: 10.8
# arrival_median_pixel_count: 8.0
# arrival_max_pixel_count: 311.0
# arrival_std_pixel_count: 11.2
# arrival_iqr_pixel_count: 5.0
#
# arrival_min_perimeter: 47.28
# arrival_mean_perimeter: 122.92
# arrival_median_perimeter: 96.15
# arrival_max_perimeter: 1575.8
# arrival_std_perimeter: 88.96
# arrival_iqr_perimeter: 62.13
#
# arrival_min_target_mean_return: 0.29
# arrival_mean_target_mean_return: 242.13
# arrival_median_target_mean_return: 177.12
# arrival_max_target_mean_return: 13017.6
# arrival_std_target_mean_return: 386.46
# ...

# %% [markdown]
# The cell below is the reason I am no longer wasting time with actually implementations by hand. Should've noticed sooner, but live and learn!

# %%
dfArrival.describe()
# Out:
#        shape_orientation   change_area  weighted_centroid_lat  \
# count        5237.000000   5237.000000            5237.000000
# mean           80.083949    606.275944              36.945544
# std            30.922210    673.578951               0.449085
# min             0.000000    282.280000              36.063761
# 25%            61.137800    361.970000              36.535304
# 50%            90.000000    422.290000              37.009403
# 75%            90.000000    603.280000              37.341059
# max           180.000000  18782.780000              37.777945
#
#        target_minimum_return  background_minimum_return  ref_graze_angle  \
# count            5237.000000                5237.000000      5237.000000
# mean               79.630699                   1.625597        52.095899
# std                82.682000                   1.793292         4.185872
# min                 0.030000                   0.000000        45.972644
# ...

# %%
os.chdir('C:\\Users\\luker\\Desktop\\d4d_work\\geojsons')

arrival_date_list = [] # track all dates of arrivals
departure_date_list = [] # track all dates of departures

dir_list = os.listdir('.') 
print("Number of folders containing geojson arrival/departure file pairs: " + str(len(dir_list)))
print("")
for i in range(len(dir_list)):
 
    #file setup 
    curr_target_dir = dir_list[i]
    curr_target_dir_path = 'C:\\Users\\luker\\Desktop\\d4d_work\\geojsons\\' + curr_target_dir
    os.chdir(curr_target_dir_path)
    file_list = os.listdir('.') 
    arrivalfname = r""+file_list[0] #arrival is always first (but also checked with if statement in processing code)
    dfArrival = gpd.read_file(arrivalfname)
    departurefname = r""+file_list[1]      
    dfDeparture = gpd.read_file(departurefname)
    
    #arrival file processing
    if dfArrival['detect_type'][0] == 'Arrival':
        print("---------- Processing arrival: " + str(i) + " ----------")
        arrival_date = dfArrival['timestamp'][0]
        arrival_date = arrival_date[0:10]
        if arrival_date not in arrival_date_list:
            arrival_date_list.append(arrival_date)
    
    #departure file processing
    if dfDeparture['detect_type'][0] == 'Departure':
        print("---------- Processing departure: " + str(i) + " ----------")
        departure_date = dfDeparture['timestamp'][0]
        departure_date = departure_date[0:10]
        if departure_date not in departure_date_list:
            departure_date_list.append(departure_date)
    
        
    #arrival_date_count_list.append(arrival_tuple)
    #departure_date_count_list.append(departure_tuple) 

print("")
print("arrival_date_list: ")
print(arrival_date_list)
print("departure_date_list: ")
print(departure_date_list)
# Out:
# Number of folders containing geojson arrival/departure file pairs: 1159
#
# ---------- Processing arrival: 0 ----------
# ---------- Processing departure: 0 ----------
# ---------- Processing arrival: 1 ----------
# ---------- Processing departure: 1 ----------
# ---------- Processing arrival: 2 ----------
# ---------- Processing departure: 2 ----------
# ---------- Processing arrival: 3 ----------
# ---------- Processing departure: 3 ----------
# ---------- Processing arrival: 4 ----------
# ---------- Processing departure: 4 ----------
# ---------- Processing arrival: 5 ----------
# ---------- Processing departure: 5 ----------
# ---------- Processing arrival: 6 ----------
# ---------- Processing departure: 6 ----------
# ---------- Processing arrival: 7 ----------
# ---------- Processing departure: 7 ----------
# ---------- Processing arrival: 8 ----------
# ---------- Processing departure: 8 ----------
# ---------- Processing arrival: 9 ----------
# ...

# %%
print(len(arrival_date_list))

print(len(departure_date_list))
# Out:
# 265
# 265
