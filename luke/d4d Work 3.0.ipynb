arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
jun_arrival_df_dict = {}
for i in arr_date_list:
    if i[4:6] == "06":
        jun_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)

jul_arrival_df_dict = {}
for i in arr_date_list:
    if i[4:6] == "07":
        jul_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
aug_arrival_df_dict = {}
for i in arr_date_list:
    if i[4:6] == "08":
        aug_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)

sep_arrival_df_dict = {}
for i in arr_date_list:
    if i[4:6] == "09":
        sep_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
oct_arrival_df_dict = {}
for i in arr_date_list:
    if i[4:6] == "10":
        oct_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
nov_arrival_df_dict = {}
for i in arr_date_list:
    if i[4:6] == "11":
        nov_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
dec_arrival_df_dict = {}
for i in arr_date_list:
    if i[4:6] == "12":
        dec_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
# Out:
# 20181113
# 20181114
# 20181115
# 20181116
# 20181117
# 20181118
# 20181119
# 20181120
# 20181121
# 20181122
# 20181123
# 20181124
# 20181125
# 20181126
# 20181127
# 20181128
# 20181129
# 20181130

# %%
jan_departure_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "01":
        jan_departure_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
feb_arrival_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "02":
        feb_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
mar_arrival_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "03":
        mar_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
apr_arrival_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "04":
        apr_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
may_arrival_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "05":
        may_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
jun_arrival_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "06":
        jun_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)

jul_arrival_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "07":
        jul_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
aug_arrival_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "08":
        aug_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)

sep_arrival_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "09":
        sep_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
oct_arrival_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "10":
        oct_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
nov_arrival_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "11":
        nov_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)
        
dec_arrival_df_dict = {}
for i in dep_date_list:
    if i[4:6] == "12":
        dec_arrival_df_dict[i] = gpd.GeoDataFrame(columns = column_names)

# %%
os.chdir('C:\\Users\\pbdin\\OneDrive\\Desktop\\d4d_work\\geojsons')
dir_list = os.listdir('.') 
print("Number of folders containing geojson arrival/departure file pairs: " + str(len(dir_list)))
print("")

# %%
for i in range(1):
 
    #file setup 
    curr_target_dir = dir_list[i]
    curr_target_dir_path = 'C:\\Users\\luker\\Desktop\\d4d_work\\geojsons\\' + curr_target_dir
    os.chdir(curr_target_dir_path)
    file_list = os.listdir('.') 
    
    arrivalfname = r""+file_list[0] #arrival is always first (but also checked with if statement in processing code)
    dfArrival = gpd.read_file(arrivalfname)
    arrival_date = dfArrival['timestamp'][0]
    arrival_date = arrival_date[0:10]
    if arrival_date
    
    departurefname = r""+file_list[1]      
    dfDeparture = gpd.read_file(departurefname)
    departure_date = dfDeparture['timestamp'][0]
    departure_date = departure_date[0:10]
    
    #gpd.GeoDataFrame(*args, **kwargs)
    
    #arrival file processing
    #if dfArrival['detect_type'][0] == 'Arrival':
    #    print("---------- Processing arrival: " + str(i) + " ----------")

        
    #if dfDeparture['detect_type'][0] == 'Departure':
    #    print("---------- Processing departure: " + str(i) + " ----------")
        

#dfArrival.head()
